# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
url = "KDDTrain+_20Percent_Description.xlsx"
df = pd.read_excel(url)
df.head()
# Out:
#    Duration Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  \
# 0         0           udp    other   SF        146          0     0
# 1         0           tcp  private   S0          0          0     0
# 2         0           tcp     http   SF        232       8153     0
# 3         0           tcp     http   SF        199        420     0
# 4         0           tcp  private  REJ          0          0     0
#
#    Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.00
# 1               0       0    0  ...                    0.10
# 2               0       0    0  ...                    1.00
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.07
#
#    Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                    0.60                         0.88
# 1                    0.05                         0.00
# 2                    0.00                         0.03
# 3                    0.00                         0.00
# 4                    0.07                         0.00
#
#    Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  1.00
# 2                         0.04                  0.03
# 3                         0.00                  0.00
# 4                         0.00                  0.00
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  Dst_host_srv_rerror_rate  \
# 0                      0.00                   0.0                      0.00
# 1                      1.00                   0.0                      0.00
# 2                      0.01                   0.0                      0.01
# 3                      0.00                   0.0                      0.00
# 4                      0.00                   1.0                      1.00
#
#    Unnamed: 41  Unnamed: 42
# 0       normal           15
# 1      neptune           19
# 2       normal           21
# 3       normal           21
# 4      neptune           21
#
# [5 rows x 43 columns]

# %%
df = df.drop(columns=['Duration', 'Unnamed: 42'])
df.head()
# Out:
#   Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  Wrong_fragment  \
# 0           udp    other   SF        146          0     0               0
# 1           tcp  private   S0          0          0     0               0
# 2           tcp     http   SF        232       8153     0               0
# 3           tcp     http   SF        199        420     0               0
# 4           tcp  private  REJ          0          0     0               0
#
#    Urgent  Hot  Num_failed_logins  ...  Dst_host_srv_count  \
# 0       0    0                  0  ...                   1
# 1       0    0                  0  ...                  26
# 2       0    0                  0  ...                 255
# 3       0    0                  0  ...                 255
# 4       0    0                  0  ...                  19
#
#    Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0                    0.00                    0.60
# 1                    0.10                    0.05
# 2                    1.00                    0.00
# 3                    1.00                    0.00
# 4                    0.07                    0.07
#
#    Dst_host_same_src_port_rate  Dst_host_srv_diff_host_rate  \
# 0                         0.88                         0.00
# 1                         0.00                         0.00
# 2                         0.03                         0.04
# 3                         0.00                         0.00
# 4                         0.00                         0.00
#
#    Dst_host_serror_rate  Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                  0.00                      0.00                   0.0
# 1                  1.00                      1.00                   0.0
# 2                  0.03                      0.01                   0.0
# 3                  0.00                      0.00                   0.0
# 4                  0.00                      0.00                   1.0
#
#    Dst_host_srv_rerror_rate  Unnamed: 41
# 0                      0.00       normal
# 1                      0.00      neptune
# 2                      0.01       normal
# 3                      0.00       normal
# 4                      1.00      neptune
#
# [5 rows x 41 columns]

# %%
df = df.rename(columns={'Unnamed: 41' : 'Attack_Type'})
df.head()
# Out:
#   Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  Wrong_fragment  \
# 0           udp    other   SF        146          0     0               0
# 1           tcp  private   S0          0          0     0               0
# 2           tcp     http   SF        232       8153     0               0
# 3           tcp     http   SF        199        420     0               0
# 4           tcp  private  REJ          0          0     0               0
#
#    Urgent  Hot  Num_failed_logins  ...  Dst_host_srv_count  \
# 0       0    0                  0  ...                   1
# 1       0    0                  0  ...                  26
# 2       0    0                  0  ...                 255
# 3       0    0                  0  ...                 255
# 4       0    0                  0  ...                  19
#
#    Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0                    0.00                    0.60
# 1                    0.10                    0.05
# 2                    1.00                    0.00
# 3                    1.00                    0.00
# 4                    0.07                    0.07
#
#    Dst_host_same_src_port_rate  Dst_host_srv_diff_host_rate  \
# 0                         0.88                         0.00
# 1                         0.00                         0.00
# 2                         0.03                         0.04
# 3                         0.00                         0.00
# 4                         0.00                         0.00
#
#    Dst_host_serror_rate  Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                  0.00                      0.00                   0.0
# 1                  1.00                      1.00                   0.0
# 2                  0.03                      0.01                   0.0
# 3                  0.00                      0.00                   0.0
# 4                  0.00                      0.00                   1.0
#
#    Dst_host_srv_rerror_rate  Attack_Type
# 0                      0.00       normal
# 1                      0.00      neptune
# 2                      0.01       normal
# 3                      0.00       normal
# 4                      1.00      neptune
#
# [5 rows x 41 columns]

# %%
df.set_index('Attack_Type', inplace=True)
df
# Out:
#             Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# Attack_Type
# normal                udp     other    SF        146          0     0
# neptune               tcp   private    S0          0          0     0
# normal                tcp      http    SF        232       8153     0
# normal                tcp      http    SF        199        420     0
# neptune               tcp   private   REJ          0          0     0
# ...                   ...       ...   ...        ...        ...   ...
# neptune               tcp      exec  RSTO          0          0     0
# warezclient           tcp  ftp_data    SF        334          0     0
# neptune               tcp   private   REJ          0          0     0
# neptune               tcp      nnsp    S0          0          0     0
# neptune               tcp    finger    S0          0          0     0
#
#              Wrong_fragment  Urgent  Hot  Num_failed_logins  ...  \
# Attack_Type                                                  ...
# normal                    0       0    0                  0  ...
# neptune                   0       0    0                  0  ...
# normal                    0       0    0                  0  ...
# normal                    0       0    0                  0  ...
# neptune                   0       0    0                  0  ...
# ...                     ...     ...  ...                ...  ...
# neptune                   0       0    0                  0  ...
# warezclient               0       0    0                  0  ...
# neptune                   0       0    0                  0  ...
# neptune                   0       0    0                  0  ...
# neptune                   0       0    0                  0  ...
#
#              Dst_host_count  Dst_host_srv_count  Dst_host_same_srv_rate  \
# Attack_Type
# normal                  255                   1                    0.00
# neptune                 255                  26                    0.10
# normal                   30                 255                    1.00
# normal                  255                 255                    1.00
# neptune                 255                  19                    0.07
# ...                     ...                 ...                     ...
# neptune                 255                   7                    0.03
# warezclient               1                  39                    1.00
# neptune                 255                  13                    0.05
# neptune                 255                  20                    0.08
# neptune                 255                  49                    0.19
#
#              Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# Attack_Type
# normal                         0.60                         0.88
# neptune                        0.05                         0.00
# normal                         0.00                         0.03
# normal                         0.00                         0.00
# neptune                        0.07                         0.00
# ...                             ...                          ...
# neptune                        0.06                         0.00
# warezclient                    0.00                         1.00
# neptune                        0.07                         0.00
# neptune                        0.06                         0.00
# neptune                        0.03                         0.01
#
#              Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# Attack_Type
# normal                              0.00                  0.00
# neptune                             0.00                  1.00
# normal                              0.04                  0.03
# normal                              0.00                  0.00
# neptune                             0.00                  0.00
# ...                                  ...                   ...
# neptune                             0.00                  0.00
# warezclient                         0.18                  0.00
# neptune                             0.00                  0.00
# neptune                             0.00                  1.00
# neptune                             0.00                  1.00
#
#              Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# Attack_Type
# normal                           0.00                   0.0
# neptune                          1.00                   0.0
# normal                           0.01                   0.0
# normal                           0.00                   0.0
# neptune                          0.00                   1.0
# ...                               ...                   ...
# neptune                          0.00                   1.0
# warezclient                      0.00                   0.0
# neptune                          0.00                   1.0
# neptune                          1.00                   0.0
# neptune                          1.00                   0.0
#
#              Dst_host_srv_rerror_rate
# Attack_Type
# normal                           0.00
# neptune                          0.00
# normal                           0.01
# normal                           0.00
# neptune                          1.00
# ...                               ...
# neptune                          1.00
# warezclient                      0.00
# neptune                          1.00
# neptune                          0.00
# neptune                          0.00
#
# [25191 rows x 40 columns]

# %%
df.drop(['pod', 'guess_passwd', 'ftp_write', 'multihop', 'rootkit', 'buffer_overflow', 'imap', 'warezmaster', 'phf', 'land', 'loadmodule', 'spy'], inplace=True)
df = df.reset_index()

# %%
df.groupby('Attack_Type').count()
# Out:
#              Protocol_type  Service   Flag  Src_bytes  Dst_bytes   Land  \
# Attack_Type
# back                   196      196    196        196        196    196
# ipsweep                710      710    710        710        710    710
# neptune               8282     8282   8282       8282       8282   8282
# nmap                   301      301    301        301        301    301
# normal               13448    13448  13448      13448      13448  13448
# portsweep              587      587    587        587        587    587
# satan                  691      691    691        691        691    691
# smurf                  529      529    529        529        529    529
# teardrop               188      188    188        188        188    188
# warezclient            181      181    181        181        181    181
#
#              Wrong_fragment  Urgent    Hot  Num_failed_logins  ...  \
# Attack_Type                                                    ...
# back                    196     196    196                196  ...
# ipsweep                 710     710    710                710  ...
# neptune                8282    8282   8282               8282  ...
# nmap                    301     301    301                301  ...
# normal                13448   13448  13448              13448  ...
# portsweep               587     587    587                587  ...
# satan                   691     691    691                691  ...
# smurf                   529     529    529                529  ...
# teardrop                188     188    188                188  ...
# warezclient             181     181    181                181  ...
#
#              Dst_host_count  Dst_host_srv_count  Dst_host_same_srv_rate  \
# Attack_Type
# back                    196                 196                     196
# ipsweep                 710                 710                     710
# neptune                8282                8282                    8282
# nmap                    301                 301                     301
# normal                13448               13448                   13448
# portsweep               587                 587                     587
# satan                   691                 691                     691
# smurf                   529                 529                     529
# teardrop                188                 188                     188
# warezclient             181                 181                     181
#
#              Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# Attack_Type
# back                            196                          196
# ipsweep                         710                          710
# neptune                        8282                         8282
# nmap                            301                          301
# normal                        13448                        13448
# portsweep                       587                          587
# satan                           691                          691
# smurf                           529                          529
# teardrop                        188                          188
# warezclient                     181                          181
#
#              Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# Attack_Type
# back                                 196                   196
# ipsweep                              710                   710
# neptune                             8282                  8282
# nmap                                 301                   301
# normal                             13448                 13448
# portsweep                            587                   587
# satan                                691                   691
# smurf                                529                   529
# teardrop                             188                   188
# warezclient                          181                   181
#
#              Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# Attack_Type
# back                              196                   196
# ipsweep                           710                   710
# neptune                          8282                  8282
# nmap                              301                   301
# normal                          13448                 13448
# portsweep                         587                   587
# satan                             691                   691
# smurf                             529                   529
# teardrop                          188                   188
# warezclient                       181                   181
#
#              Dst_host_srv_rerror_rate
# Attack_Type
# back                              196
# ipsweep                           710
# neptune                          8282
# nmap                              301
# normal                          13448
# portsweep                         587
# satan                             691
# smurf                             529
# teardrop                          188
# warezclient                       181
#
# [10 rows x 40 columns]

# %%
lista_normal = df[df['Attack_Type'] == 'normal'].index.tolist()
lista_ipsweep = df[df['Attack_Type'] == 'ipsweep'].index.tolist()
lista_neptune = df[df['Attack_Type'] == 'neptune'].index.tolist()
lista_portsweep = df[df['Attack_Type'] == 'portaweep'].index.tolist()
lista_satan = df[df['Attack_Type'] == 'satan'].index.tolist()
lista_smurf = df[df['Attack_Type'] == 'smurf'].index.tolist()

# %%
for i, indice in enumerate(lista_normal):
    if len(lista_normal) - 200 == i:
        break
    df.drop(indice, inplace=True)

for i, indice in enumerate(lista_ipsweep):
    if len(lista_ipsweep) - 200 == i:
        break
    df.drop(indice, inplace=True)

for i, indice in enumerate(lista_neptune):
    if len(lista_neptune) - 200 == i:
        break
    df.drop(indice, inplace=True)

for i, indice in enumerate(lista_portsweep):
    if len(lista_portsweep) - 200 == i:
        break
    df.drop(indice, inplace=True)

for i, indice in enumerate(lista_satan):
    if len(lista_satan) - 200 == i:
        break
    df.drop(indice, inplace=True)

for i, indice in enumerate(lista_smurf):
    if len(lista_smurf) - 200 == i:
        break
    df.drop(indice, inplace=True)

# %%
lista_normal = df[df['Attack_Type'] == 'normal'].index.tolist()
len(lista_normal)
# Out:
# 200

# %%
df['Protocol_type'].unique()
# Out:
# array(['tcp', 'udp', 'icmp'], dtype=object)

# %%
df['Service'].unique()
# Out:
# array(['ftp_data', 'private', 'eco_i', 'netbios_dgm', 'gopher', 'other',
#        'ftp', 'sql_net', 'time', 'http', 'remote_job', 'csnet_ns', 'ssh',
#        'Z39_50', 'telnet', 'systat', 'iso_tsap', 'netbios_ns', 'echo',
#        'bgp', 'whois', 'nntp', 'kshell', 'klogin', 'ldap', 'link', 'name',
#        'ecr_i', 'exec', 'uucp_path', 'finger', 'discard', 'imap4',
#        'http_443', 'netstat', 'daytime', 'pop_3', 'smtp', 'efs', 'supdup',
#        'ctf', 'mtp', 'rje', 'nnsp', 'hostnames', 'netbios_ssn', 'pm_dump',
#        'courier', 'uucp', 'domain_u', 'domain', 'auth', 'login', 'sunrpc',
#        'vmnet', 'X11', 'IRC', 'urp_i'], dtype=object)

# %%
df['Flag'].unique()
# Out:
# array(['SF', 'REJ', 'RSTR', 'SH', 'S0', 'RSTOS0', 'S2', 'OTH', 'RSTO',
#        'S1'], dtype=object)

# %%
df['Attack_Type'].unique()
# Out:
# array(['warezclient', 'portsweep', 'teardrop', 'nmap', 'back', 'smurf',
#        'satan', 'ipsweep', 'neptune', 'normal'], dtype=object)

# %%
le = preprocessing.LabelEncoder()

le.fit(['udp', 'tcp', 'icmp'])
Protocol_type = le.transform(df['Protocol_type'])
df['Protocol_type'] = Protocol_type

le.fit(['other', 'private', 'http', 'remote_job', 'ftp_data', 'name',
        'netbios_ns', 'eco_i', 'mtp', 'telnet', 'finger', 'domain_u',
        'supdup', 'uucp_path', 'Z39_50', 'smtp', 'csnet_ns', 'uucp',
        'netbios_dgm', 'urp_i', 'auth', 'domain', 'ftp', 'bgp', 'ldap',
        'ecr_i', 'gopher', 'vmnet', 'systat', 'http_443', 'efs', 'whois',
        'imap4', 'iso_tsap', 'echo', 'klogin', 'link', 'sunrpc', 'login',
        'kshell', 'sql_net', 'time', 'hostnames', 'exec', 'ntp_u',
        'discard', 'nntp', 'courier', 'ctf', 'ssh', 'daytime', 'shell',
        'netstat', 'pop_3', 'nnsp', 'IRC', 'pop_2', 'printer', 'tim_i',
        'pm_dump', 'red_i', 'netbios_ssn', 'rje', 'X11', 'urh_i',
        'http_8001'])
Service = le.transform(df['Service'])
df['Service'] = Service

le.fit(['SF', 'S0', 'REJ', 'RSTR', 'SH', 'RSTO', 'S1', 'RSTOS0', 'S3',
        'S2', 'OTH'])
Flag = le.transform(df['Flag'])
df['Flag'] = Flag
le.fit(['normal', 'neptune', 'teardrop', 'warezclient', 'ipsweep', 'portsweep', 'nmap', 'satan', 'smurf', 'back'])
Attack_Type = le.transform(df['Attack_Type'])
df['Attack_Type'] = Attack_Type
df
# Out:
#        Attack_Type  Protocol_type  Service  Flag  Src_bytes  Dst_bytes  Land  \
# 12               9              1       19     9        334          0     0
# 32               5              1       46     1          0          0     0
# 45               8              2       46     9         28          0     0
# 47               9              1       19     9        334          0     0
# 51               8              2       46     9         28          0     0
# ...            ...            ...      ...   ...        ...        ...   ...
# 25108            2              1       16     2          0          0     0
# 25109            9              1       19     9        334          0     0
# 25110            2              1       46     1          0          0     0
# 25111            2              1       38     5          0          0     0
# 25112            2              1       17     5          0          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_count  Dst_host_srv_count  \
# 12                  0       0    0  ...               2                  20
# 32                  0       0    0  ...             255                   1
# 45                  3       0    0  ...             255                  80
# 47                  0       0    0  ...               4                  38
# 51                  3       0    0  ...             255                   2
# ...               ...     ...  ...  ...             ...                 ...
# 25108               0       0    0  ...             255                   7
# 25109               0       0    0  ...               1                  39
# 25110               0       0    0  ...             255                  13
# 25111               0       0    0  ...             255                  20
# 25112               0       0    0  ...             255                  49
#
#        Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 12                       1.00                    0.00
# 32                       0.00                    0.31
# 45                       0.31                    0.02
# 47                       1.00                    0.00
# 51                       0.01                    0.02
# ...                       ...                     ...
# 25108                    0.03                    0.06
# 25109                    1.00                    0.00
# 25110                    0.05                    0.07
# 25111                    0.08                    0.06
# 25112                    0.19                    0.03
#
#        Dst_host_same_src_port_rate  Dst_host_srv_diff_host_rate  \
# 12                            1.00                         0.20
# 32                            0.28                         0.00
# 45                            0.31                         0.00
# 47                            1.00                         0.18
# 51                            0.01                         0.00
# ...                            ...                          ...
# 25108                         0.00                         0.00
# 25109                         1.00                         0.18
# 25110                         0.00                         0.00
# 25111                         0.00                         0.00
# 25112                         0.01                         0.00
#
#        Dst_host_serror_rate  Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 12                      0.0                       0.0                  0.00
# 32                      0.0                       0.0                  0.29
# 45                      0.0                       0.0                  0.00
# 47                      0.0                       0.0                  0.00
# 51                      0.0                       0.0                  0.77
# ...                     ...                       ...                   ...
# 25108                   0.0                       0.0                  1.00
# 25109                   0.0                       0.0                  0.00
# 25110                   0.0                       0.0                  1.00
# 25111                   1.0                       1.0                  0.00
# 25112                   1.0                       1.0                  0.00
#
#        Dst_host_srv_rerror_rate
# 12                          0.0
# 32                          1.0
# 45                          0.0
# 47                          0.0
# 51                          0.0
# ...                         ...
# 25108                       1.0
# 25109                       0.0
# 25110                       1.0
# 25111                       0.0
# 25112                       0.0
#
# [2453 rows x 41 columns]

# %%
x = df.drop(columns='Attack_Type')
y = df['Attack_Type']

x
# Out:
#        Protocol_type  Service  Flag  Src_bytes  Dst_bytes  Land  \
# 12                 1       19     9        334          0     0
# 32                 1       46     1          0          0     0
# 45                 2       46     9         28          0     0
# 47                 1       19     9        334          0     0
# 51                 2       46     9         28          0     0
# ...              ...      ...   ...        ...        ...   ...
# 25108              1       16     2          0          0     0
# 25109              1       19     9        334          0     0
# 25110              1       46     1          0          0     0
# 25111              1       38     5          0          0     0
# 25112              1       17     5          0          0     0
#
#        Wrong_fragment  Urgent  Hot  Num_failed_logins  ...  Dst_host_count  \
# 12                  0       0    0                  0  ...               2
# 32                  0       0    0                  0  ...             255
# 45                  3       0    0                  0  ...             255
# 47                  0       0    0                  0  ...               4
# 51                  3       0    0                  0  ...             255
# ...               ...     ...  ...                ...  ...             ...
# 25108               0       0    0                  0  ...             255
# 25109               0       0    0                  0  ...               1
# 25110               0       0    0                  0  ...             255
# 25111               0       0    0                  0  ...             255
# 25112               0       0    0                  0  ...             255
#
#        Dst_host_srv_count  Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 12                     20                    1.00                    0.00
# 32                      1                    0.00                    0.31
# 45                     80                    0.31                    0.02
# 47                     38                    1.00                    0.00
# 51                      2                    0.01                    0.02
# ...                   ...                     ...                     ...
# 25108                   7                    0.03                    0.06
# 25109                  39                    1.00                    0.00
# 25110                  13                    0.05                    0.07
# 25111                  20                    0.08                    0.06
# 25112                  49                    0.19                    0.03
#
#        Dst_host_same_src_port_rate  Dst_host_srv_diff_host_rate  \
# 12                            1.00                         0.20
# 32                            0.28                         0.00
# 45                            0.31                         0.00
# 47                            1.00                         0.18
# 51                            0.01                         0.00
# ...                            ...                          ...
# 25108                         0.00                         0.00
# 25109                         1.00                         0.18
# 25110                         0.00                         0.00
# 25111                         0.00                         0.00
# 25112                         0.01                         0.00
#
#        Dst_host_serror_rate  Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 12                      0.0                       0.0                  0.00
# 32                      0.0                       0.0                  0.29
# 45                      0.0                       0.0                  0.00
# 47                      0.0                       0.0                  0.00
# 51                      0.0                       0.0                  0.77
# ...                     ...                       ...                   ...
# 25108                   0.0                       0.0                  1.00
# 25109                   0.0                       0.0                  0.00
# 25110                   0.0                       0.0                  1.00
# 25111                   1.0                       1.0                  0.00
# 25112                   1.0                       1.0                  0.00
#
#        Dst_host_srv_rerror_rate
# 12                          0.0
# 32                          1.0
# 45                          0.0
# 47                          0.0
# 51                          0.0
# ...                         ...
# 25108                       1.0
# 25109                       0.0
# 25110                       1.0
# 25111                       0.0
# 25112                       0.0
#
# [2453 rows x 40 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
print(len(X_train), ' ', len(X_test), ' ', len(y_train), ' ', len(y_test))
# Out:
# 1717   736   1717   736

# %%
print('Ajuste da topologia...')
num_entrada = X_train.shape[1]
num_saida = len(df['Attack_Type'].unique())
print(f'Entradas = %i \nSaídas = %i'%(num_entrada, num_saida))

while True:
    num_camada_escondida = int(input('Digite o número de camadas ocultas: '))
    if(num_camada_escondida > 0):
        break


topologia = []
for i in range(0, num_camada_escondida):
    num = int(input(f'Quantidade de neurônios na {i+1}ª camada oculta: '))
    topologia.append(num)
    while(num <= 0):
        num = int(input(f'Quantidade de neurônios na {i+1}ª camada oculta: '))
        break

epocas = int(input('Digite o número de épocas: '))
# Out:
# Ajuste da topologia...
# Entradas = 40
# Saídas = 10

# %%
Modelo = MLPClassifier(hidden_layer_sizes=tuple(topologia), activation='tanh', max_iter=epocas, random_state=42, verbose=True)

topologia.insert(0, num_entrada)
topologia.append(num_saida)

modelo = Modelo.fit(X_train, y_train)

print(modelo)
print('Topologia da MLP = ', topologia)

plt.plot(modelo.loss_curve_)
plt.title('Histórico de Perda Logarítmica')
plt.xlabel('épocas')
plt.ylabel('perda')
# Out:
# Iteration 1, loss = 2.48304857
# Iteration 2, loss = 2.38288549
# Iteration 3, loss = 2.30039424
# Iteration 353, loss = 0.23055065
# Iteration 354, loss = 0.23630031
# Iteration 355, loss = 0.22339115
# Iteration 356, loss = 0.24426769
# Iteration 357, loss = 0.23911731
# Iteration 358, loss = 0.22696438
# Iteration 359, loss = 0.22834690
# Iteration 360, loss = 0.22222612
# Iteration 361, loss = 0.21982701
# Iteration 362, loss = 0.22016041
# Iteration 363, loss = 0.22381532
# Iteration 364, loss = 0.22577441
# Iteration 365, loss = 0.21760892
# Iteration 366, loss = 0.22537593
# Iteration 367, loss = 0.22032889
# Iteration 368, loss = 0.21992124
# Iteration 369, loss = 0.22405489
# Iteration 370, loss = 0.22265409
# Iteration 371, loss = 0.21898747
# Iteration 372, loss = 0.22776068
# Iteration 373, loss = 0.22113389
# Iteration 374, loss = 0.22444276
# Iteration 375, loss = 0.21659242
# Iteration 376, loss = 0.21652143
# Iteration 377, loss = 0.21294887
# Iteration 378, loss = 0.24569477
# Iteration 379, loss = 0.22801913
# Iteration 380, loss = 0.24450444
# Iteration 381, loss = 0.22746985
# Iteration 382, loss = 0.22345065
# Iteration 383, loss = 0.21946235
# Iteration 384, loss = 0.21038596
# Iteration 385, loss = 0.21345620
# Iteration 386, loss = 0.21115562
# Iteration 387, loss = 0.20811268
# Iteration 388, loss = 0.20840458
# Iteration 389, loss = 0.21574875
# Iteration 390, loss = 0.21446093
# Iteration 391, loss = 0.21655755
# Iteration 392, loss = 0.21949745
# Iteration 393, loss = 0.21866354
# Iteration 394, loss = 0.21611350
# Iteration 395, loss = 0.21754516
# Iteration 396, loss = 0.22589986
# Iteration 397, loss = 0.22394924
# Iteration 398, loss = 0.26917329
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='tanh', hidden_layer_sizes=(9, 9, 9, 10, 10),
#               max_iter=5000, random_state=42, verbose=True)
# Topologia da MLP =  [40, 9, 9, 9, 10, 10, 10]
# Text(0, 0.5, 'perda')

# %%
teste_modelo = modelo.predict(X_test)

# %%
df['Attack_Type'] = le.inverse_transform(df['Attack_Type'])
labels = df['Attack_Type'].unique()
print(labels)
# Out:
# ['warezclient' 'portsweep' 'teardrop' 'nmap' 'back' 'smurf' 'satan'
#  'ipsweep' 'neptune' 'normal']

# %%
import seaborn as sns; sns.set()
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

mat = confusion_matrix(y_test, teste_modelo)
plt.figure(1, figsize=(10, 7))
sns.heatmap(mat, annot=True, vmin=0, fmt='.0f', vmax=200, xticklabels=labels, yticklabels=labels, cmap="rocket")
#sns.set(font_scale=0.5)
plt.xlabel('Real')
plt.ylabel('Estimado')

print(classification_report(y_test, teste_modelo))
acuracia = metrics.accuracy_score(teste_modelo, y_test) * 100
print('A acurácia é %.2f%%' %  acuracia)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94        63
#            1       0.92      0.93      0.93        75
#            2       0.98      1.00      0.99        50
#            3       0.81      0.89      0.85        92
#            4       0.85      0.76      0.80        51
#            5       0.91      1.00      0.95       174
#            6       1.00      0.65      0.79        72
#            7       1.00      0.78      0.88        65
#            8       0.86      1.00      0.93        51
#            9       0.86      0.98      0.91        43
#
#     accuracy                           0.90       736
#    macro avg       0.91      0.90      0.90       736
# weighted avg       0.91      0.90      0.90       736
#
# A acurácia é 90.49%
